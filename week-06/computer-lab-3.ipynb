# %% [markdown]
# # COMPUTER LAB 3
#
# Work through the "Third Computer Lab" (Chapter 9) in _A Student's Guide to Python._  This exercise illustrates how to work with images in Python.
#
# You can use this notebook to store your code, plots, and notes, or you can write a ___script___ (see Section 3.3) that will carry out the analysis and produce the plots, and simply write your comments and observations in this notebook.  If you write a script, it should save your plots and images to PDF, JPG, or PNG files in this folder when it runs.

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

import scipy as sc
from scipy.signal import convolve

from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from numpy.random import default_rng

# %%
impulse = np.zeros( (51, 51))
impulse[25,25] = 1.0
my_filter = np.ones( (3,3) )/ 9
response = convolve(impulse, my_filter)
plt.figure()
plt.imshow(response)

# %%
gauss_fil = np.loadtxt("gauss_filter.csv", delimiter=',')

# %%
cat = plt.imread('bwCat.tif')
plt.imshow(cat)

# %%
small_square_filter = convolve(gauss_fil, my_filter)
plt.figure()
plt.imshow(small_square_filter)

# %%
small_square_filter = convolve(cat, my_filter)
plt.figure()
plt.imshow(small_square_filter)

# %%
my_filter = np.ones( (15, 15) )/ 9

large_square_filter = convolve(gauss_fil, my_filter)
plt.figure()
plt.imshow(large_square_filter)

# %%
#The yellow dot in the center of the image grows slighty and that can be also seen in the change of the x and y axis variables of the graphic. In addition to this, altering the size of the filter for the array that then is put through convolution changes the reaction of the pixelation and image throughout the edges of the graphic.

# %%
plt.imshow(response)

large_square_filter = convolve(gauss_fil, my_filter)
plt.figure()
plt.imshow(large_square_filter)

# %%
conv = convolve(response,large_square_filter)
thirD = ax.plot_surface(conv,conv,conv,rstride=1,cstride=1)

plt.figure(thirD)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_70920/1589483350.py in <module>
#       2 thirD = ax.plot_surface(conv,conv,conv,rstride=1,cstride=1)
#       3
# ----> 4 plt.figure(thirD)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781             num = allnums[inum]
#     782     else:
# --> 783         num = int(num)  # crude validation of num argument
#     784
#     785     manager = _pylab_helpers.Gcf.get_fig_manager(num)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'Poly3DCollection'

# %%
rng = default_rng()
rand = rng.random

noisy = rand((648,864))
noisy_kitty = noisy*cat

# %%
noisy2 = rand((662,878))
sml_noisy_kitty = noisy2*small_square_filter

# %%
noisy3 = rand((692,908))
large_square_filter = convolve(gauss_fil, cat)
lrg_noisy_kitty = noisy3*large_square_filter

# %%
plt.figure()
plt.imshow(cat)

plt.figure()
plt.imshow(noisy_kitty)

plt.figure()
plt.imshow(sml_noisy_kitty)

plt.figure()
plt.imshow(lrg_noisy_kitty)

# %%
v = np.arange(-25, 26)
X, Y = np.meshgrid(v,v)
gauss_filter = np.exp(-.5*(X**2/2 + Y**2/45))

# %%
ax = Axes3D(plt.figure())
ax.plot_surface(X,Y,gauss_filter)
# Out:
# C:\Users\hanna\AppData\Local\Temp/ipykernel_70920/2106672924.py:1: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(plt.figure())

# %%
laplace_filter = np.array([[0,-1,0],[-1,4,-1],[0,-1,0]])
combined_filter = convolve(gauss_filter,laplace_filter,mode='valid')

# %%
ax = Axes3D(plt.figure())
ax.plot_surface(combined_filter,combined_filter,combined_filter)
# Out:
# C:\Users\hanna\AppData\Local\Temp/ipykernel_70920/2297664862.py:1: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(plt.figure())

# %%
laplace_filter = np.array(cat)
combined_filter = convolve(gauss_filter,laplace_filter,mode='valid')

# %%
ax = Axes3D(plt.figure())
ax.plot_surface(combined_filter,combined_filter,combined_filter)
# Out:
# C:\Users\hanna\AppData\Local\Temp/ipykernel_70920/2297664862.py:1: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(plt.figure())

# %%
plt.figure()
plt.imshow(combined_filter,vmin=0,vmax=.5*combined_filter.max())

# %%
stress = np.loadtxt('stressFibers.csv',delimiter =',')
plt.figure()
plt.imshow(stress)

# %%
stress_combined = convolve(stress,combined_filter)

plt.figure()
plt.imshow(stress_combined,vmin=0,vmax=.5*stress_combined.max())

# %%
v = np.arange(0, 255)
X, Y = np.meshgrid(v,v)
gauss_filter = np.exp(-.5*(X**2/2 + Y**2/45))

# %%
new_filter = gauss_filter.astype('unit8')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_70920/3003002599.py in <module>
# ----> 1 new_filter = gauss_filter.astype('unit8')
#
# TypeError: data type 'unit8' not understood
