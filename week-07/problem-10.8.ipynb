# %% [markdown]
# # 10.8 PROBABILITY OF ZERO COPIES
#
# Use this notebook to store your work for this problem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as ss
from numpy import random
from scipy.stats import norm
from scipy.special import beta
from numpy.random import default_rng

rand = default_rng().random

# %%
cycles = 150
mean = []

for k in range(300):
    loc_array = []
    
    for j in range(cycles):
        B = 1
        N = 300
        u = rand(N)
        y = -np.log(u)
        t = y/B
        time = t.cumsum()
        xi = 0.5
        steps = 2*(rand(N) < xi) - 1
        location = steps.cumsum()
  
        loc_array = np.append(loc_array,location[k])
        mean_cycle = np.mean(loc_array)

    mean = np.append(mean,mean_cycle)

plt.plot(time,mean,'r-')
plt.title("Mean vs Time")
# Out:
# Text(0.5, 1.0, 'Mean vs Time')

# %%
plt.semilogy(time,mean)
plt.title('Semi-log Plot of Mean vs Time')
# Out:
# Text(0.5, 1.0, 'Semi-log Plot of Mean vs Time')

# %% [markdown]
# ***REPLACE WITH YOUR COMMENTS.***
